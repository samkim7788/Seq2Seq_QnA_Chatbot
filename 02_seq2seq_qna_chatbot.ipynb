# %% [markdown]
# # Seq2Seq Q&A Chatbot 구현

# %% [markdown]
# ### 데이터 취득

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/songys/Chatbot_data/refs/heads/master/ChatbotData.csv')
df = df[['Q', 'A']]
df
# Out:
#                              Q                         A
# 0                       12시 땡!                하루가 또 가네요.
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.
# 4                      PPL 심하네                눈살이 찌푸려지죠.
# ...                        ...                       ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.
# 11820              흑기사 해주는 짝남.                    설렜겠어요.
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.
#
# [11823 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11823 entries, 0 to 11822
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       11823 non-null  object
#  1   A       11823 non-null  object
# dtypes: object(2)
# memory usage: 184.9+ KB

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# ##### 토커나이저 학습 (sentencepiece 활용)
#
# - 접두사, 접미사 처리 (bos, eos)
#      - Train() 인자 cmd 옵션을 추가 (`<bos>, <eos>, <pad>, <oov>...`)<br>
#        set_encode_extra_options(':')<br>
#        set_encode_extra_options('bos:')<br>
#        set_encode_extra_options(':eos')<br>
#        set_encode_extra_options('bos:eos')

# %%
df[['Q','A']].stack().to_csv("train.txt", index=False, header=False)

# %%
import sentencepiece as spt

spt.SentencePieceTrainer.Train(
    input='train.txt',
    model_prefix='qna',
    vocab_size=5000
)

# %%
import sentencepiece as spt

sp = spt.SentencePieceProcessor()
sp.Load("qna.model")

for doc in df['Q'].values[:3]:
    print("원문:", doc)
    print("pieces:", sp.encode_as_pieces(doc)) 
    print("ids:", sp.encode_as_ids(doc))        
    print()
# Out:
# 원문: 12시 땡!
# pieces: ['▁12', '시', '▁', '땡', '!']
# ids: [4230, 298, 4, 4827, 71]
#
# 원문: 1지망 학교 떨어졌어
# pieces: ['▁1', '지', '망', '▁학교', '▁떨어졌어']
# ids: [290, 13, 896, 672, 1740]
#
# 원문: 3박4일 놀러가고 싶다
# pieces: ['▁3', '박', '4', '일', '▁놀러가고', '▁싶다']
# ids: [276, 1285, 2304, 75, 2963, 93]

# %% [markdown]
# ##### 학습용 데이터 Q_input, A_input, A_target 생성

# %%
VOCAB_SIZE = 10000

# %%
Q_inputs = []
A_inputs = []
A_tagets = []

for q, a in zip(df['Q'], df['A']):
        a_input = '<bos> ' + a
        a_taget = a + ' <eos>'

        Q_inputs.append(q)
        A_inputs.append(a_input)
        A_tagets.append(a_taget)

len(Q_inputs), len(A_inputs), len(A_tagets)
# Out:
# (11823, 11823, 11823)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

Q_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<OOV>')
Q_tokenizer.fit_on_texts(Q_inputs)
Q_inputs_seq = Q_tokenizer.texts_to_sequences(Q_inputs)

Q_inputs_seq[2500:2505]
# Out:
# [[1559, 6061, 6], [1559, 104], [1559, 6062, 6063], [1559, 526], [3248, 3249]]

# %%
q_num_words = min(VOCAB_SIZE, len(Q_tokenizer.word_index))
q_max_len = max([len(seq) for seq in Q_inputs_seq])

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
A_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<OOV', filters='')
A_tokenizer.fit_on_texts(A_inputs + A_tagets)

A_inputs_seq = A_tokenizer.texts_to_sequences(A_inputs)
A_targets_seq = A_tokenizer.texts_to_sequences(A_tagets)

# %%
A_tokenizer.index_word
# Out:
# {1: '<OOV',
#  2: '<bos>',
#  3: '<eos>',
#  4: '거예요.',
#  5: '수',
#  6: '더',
#  7: '같아요.',
#  8: '좋은',
#  9: '있어요.',
#  10: '잘',
#  11: '있을',
#  12: '많이',
#  13: '것',
#  14: '게',
#  15: '마세요.',
#  16: '해보세요.',
#  17: '건',
#  18: '수도',
#  19: '거',
#  20: '마음이',
#  21: '좋을',
#  22: '없어요.',
#  23: '시간이',
#  24: '그',
#  25: '안',
#  26: '될',
#  27: '것도',
#  28: '다른',
#  29: '바랄게요.',
#  30: '사람',
#  31: '돼요.',
#  32: '좀',
#  33: '저도',
#  34: '있는',
#  35: '그런',
#  36: '보세요.',
#  37: '너무',
#  38: '하세요.',
#  39: '좋아요.',
#  40: '않아요.',
#  41: '제가',
#  42: '바랍니다.',
#  43: '그럴',
#  44: '할',
#  45: '걸',
#  46: '드세요.',
#  47: '같이',
#  48: '해요.',
#  49: '좋죠.',
#  50: '생각해요.',
#  51: '말해보세요.',
#  52: '사람이',
#  53: '좋겠어요.',
#  54: '마음을',
#  55: '먼저',
#  56: '몰라요.',
#  57: '이제',
#  58: '하고',
#  59: '일이',
#  60: '자신을',
#  61: '다',
#  62: '생각해보세요.',
#  63: '하는',
#  64: '아니에요.',
#  65: '정말',
#  66: '좋겠네요.',
#  67: '힘든',
#  68: '다시',
#  69: '마음',
#  70: '있으면',
#  71: '때',
#  72: '한',
#  73: '바라요.',
#  74: '그게',
#  75: '많은',
#  76: '주세요.',
#  77: '사랑은',
#  78: '찾아보세요.',
#  79: '말고',
#  80: '만큼',
#  81: '어떨까요.',
#  82: '가보세요.',
#  83: '저는',
#  84: '아직',
#  85: '직접',
#  86: '좋아하는',
#  87: '그렇게',
#  88: '생각을',
#  89: '괜찮아요.',
#  90: '때가',
#  91: '도움이',
#  92: '충분히',
#  93: '물어보세요.',
#  94: '않을',
#  95: '사람은',
#  96: '시간',
#  97: '있죠.',
#  98: '쉽지',
#  99: '항상',
#  100: '않는',
#  101: '말아요.',
#  102: '연락해보세요.',
#  103: '얼른',
#  104: '대화를',
#  105: '새로운',
#  106: '힘들',
#  107: '사람을',
#  108: '당신의',
#  109: '따라',
#  110: '있나봐요.',
#  111: '올',
#  112: '마음의',
#  113: '없는',
#  114: '하지',
#  115: '중요해요.',
#  116: '오세요.',
#  117: '서로',
#  118: '자신의',
#  119: '무슨',
#  120: '생각이',
#  121: '싶은',
#  122: '함께',
#  123: '만날',
#  124: '중요한',
#  125: '하면',
#  126: '조심하세요.',
#  127: '사랑이',
#  128: '어떤',
#  129: '조금만',
#  130: '조금',
#  131: '가장',
#  132: '잘할',
#  133: '혼자',
#  134: '열심히',
#  135: '저랑',
#  136: '큰',
#  137: '조금씩',
#  138: '꼭',
#  139: '사랑을',
#  140: '거라',
#  141: '그래도',
#  142: '또',
#  143: '못',
#  144: '천천히',
#  145: '마음에',
#  146: '가는',
#  147: '모르겠어요.',
#  148: '사랑의',
#  149: '이별은',
#  150: '맛있게',
#  151: '계속',
#  152: '지금도',
#  153: '당신을',
#  154: '보고',
#  155: '않은',
#  156: '내',
#  157: '생각보다',
#  158: '당신이',
#  159: '봐요.',
#  160: '먹고',
#  161: '사세요.',
#  162: '지금',
#  163: '많았어요.',
#  164: '뿐이에요.',
#  165: '믿어요.',
#  166: '있다면',
#  167: '하죠.',
#  168: '되길',
#  169: '하나씩',
#  170: '서로에게',
#  171: '대한',
#  172: '인연이',
#  173: '참',
#  174: '살',
#  175: '잠시',
#  176: '정리가',
#  177: '않죠.',
#  178: '이별을',
#  179: '있었나봐요.',
#  180: '시간을',
#  181: '신경쓰지',
#  182: '사랑',
#  183: '볼',
#  184: '알',
#  185: '언젠간',
#  186: '모두',
#  187: '곳으로',
#  188: '확신이',
#  189: '싶어요.',
#  190: '거죠.',
#  191: '친구가',
#  192: '주무세요.',
#  193: '연락을',
#  194: '덜',
#  195: '싶네요.',
#  196: '없죠.',
#  197: '눈을',
#  198: '필요해요.',
#  199: '네',
#  200: '늦지',
#  201: '가져보세요.',
#  202: '해주세요.',
#  203: '필요한',
#  204: '나쁜',
#  205: '되지',
#  206: '없을',
#  207: '자신이',
#  208: '확인해보세요.',
#  209: '당신은',
#  210: '생각',
#  211: '살펴보세요.',
#  212: '금방',
#  213: '없네요.',
#  214: '사랑해주세요.',
#  215: '힘들죠.',
#  216: '않아도',
#  217: '아니라',
#  218: '나를',
#  219: '많아요.',
#  220: '진짜',
#  221: '예의가',
#  222: '언제나',
#  223: '변화가',
#  224: '말을',
#  225: '슬픈',
#  226: '힘들어요.',
#  227: '아무래도',
#  228: '오늘',
#  229: '좋아할',
#  230: '쉬운',
#  231: '이유가',
#  232: '없다면',
#  233: '중요하지',
#  234: '사는',
#  235: '가세요.',
#  236: '즐거운',
#  237: '곧',
#  238: '해봐요.',
#  239: '미리',
#  240: '잘하고',
#  241: '지금은',
#  242: '그래요.',
#  243: '대로',
#  244: '사랑하는',
#  245: '힘내세요.',
#  246: '힘들겠지만',
#  247: '이젠',
#  248: '주는',
#  249: '제일',
#  250: '만나지',
#  251: '누구나',
#  252: '같은',
#  253: '다를',
#  254: '위해',
#  255: '사람들이',
#  256: '원하는',
#  257: '마요.',
#  258: '않길',
#  259: '나중에',
#  260: '사랑했던',
#  261: '사람도',
#  262: '확실한',
#  263: '시간은',
#  264: '친구를',
#  265: '기분이',
#  266: '자연스러운',
#  267: '잘하는',
#  268: '맞는',
#  269: '다행이에요.',
#  270: '감정을',
#  271: '맛있는',
#  272: '스스로',
#  273: '기분',
#  274: '좋겠죠.',
#  275: '생길',
#  276: '일찍',
#  277: '상관',
#  278: '감기',
#  279: '연락',
#  280: '편이',
#  281: '사랑에',
#  282: '않는다면',
#  283: '번',
#  284: '자책하지',
#  285: '가끔',
#  286: '다음에는',
#  287: '않고',
#  288: '그러면',
#  289: '바로',
#  290: '말하세요.',
#  291: '사람이네요.',
#  292: '모든',
#  293: '스트레스',
#  294: '전에',
#  295: '힘들겠어요.',
#  296: '날이',
#  297: '그냥',
#  298: '같네요.',
#  299: '물어보는',
#  300: '충분한',
#  301: '그건',
#  302: '사람마다',
#  303: '꾸준히',
#  304: '만나보세요.',
#  305: '것보다',
#  306: '멋진',
#  307: '있겠어요.',
#  308: '있잖아요.',
#  309: '오래',
#  310: '자주',
#  311: '해도',
#  312: '것이',
#  313: '용기를',
#  314: '보는',
#  315: '술',
#  316: '있네요.',
#  317: '마음은',
#  318: '후회하지',
#  319: '생각하고',
#  320: '되겠네요.',
#  321: '잠깐',
#  322: '신경',
#  323: '그런가봐요.',
#  324: '어려운',
#  325: '봅니다.',
#  326: '절대',
#  327: '자신에게',
#  328: '앞에',
#  329: '받을',
#  330: '적당히',
#  331: '내가',
#  332: '되는',
#  333: '데이트',
#  334: '뭐든',
#  335: '아는',
#  336: '일이에요.',
#  337: '아픈',
#  338: '매일',
#  339: '일은',
#  340: '준비가',
#  341: '미련이',
#  342: '썸',
#  343: '후회할',
#  344: '서로를',
#  345: '모르는',
#  346: '생각하세요.',
#  347: '일을',
#  348: '말씀해주세요.',
#  349: '나을',
#  350: '한번',
#  351: '놀아요.',
#  352: '연습을',
#  353: '때까지',
#  354: '만나세요.',
#  355: '해야',
#  356: '자신감을',
#  357: '아무것도',
#  358: '같습니다.',
#  359: '합니다.',
#  360: '있는지',
#  361: '시작해보세요.',
#  362: '관심을',
#  363: '맘고생',
#  364: '끝을',
#  365: '딱',
#  366: '놓아주세요.',
#  367: '받아들이는',
#  368: '힘들게',
#  369: '집에',
#  370: '현상이에요.',
#  371: '때도',
#  372: '이야기해보세요.',
#  373: '아닌',
#  374: '말씀해보세요.',
#  375: '제',
#  376: '되어',
#  377: '말',
#  378: '살짝',
#  379: '고민이',
#  380: '보면',
#  381: '곳이',
#  382: '된',
#  383: '해보는',
#  384: '것을',
#  385: '중에',
#  386: '긴',
#  387: '작은',
#  388: '모르겠네요.',
#  389: '어떨까요?',
#  390: '문제가',
#  391: '좋지',
#  392: '않았어요.',
#  393: '요즘',
#  394: '사람이에요.',
#  395: '궁금하네요.',
#  396: '힘이',
#  397: '쉬세요.',
#  398: '고생',
#  399: '여유를',
#  400: '줄',
#  401: '연애',
#  402: '추억이',
#  403: '들',
#  404: '둘',
#  405: '생각해',
#  406: '잊지',
#  407: '사귀는',
#  408: '저에게',
#  409: '들어드릴게요.',
#  410: '보지',
#  411: '마음도',
#  412: '이별이',
#  413: '어느덧',
#  414: '지켜보세요.',
#  415: '만들어',
#  416: '노력해보세요.',
#  417: '위한',
#  418: '되죠.',
#  419: '않으면',
#  420: '지쳤나봐요.',
#  421: '왜',
#  422: '이야기네요.',
#  423: '주변',
#  424: '고민하고',
#  425: '예뻐요.',
#  426: '하다보면',
#  427: '잊어버리세요.',
#  428: '잔',
#  429: '이해해주세요.',
#  430: '아닌지',
#  431: '가서',
#  432: '괜찮을',
#  433: '많죠.',
#  434: '먹으면',
#  435: '걸로',
#  436: '전해보세요.',
#  437: '있으니까요.',
#  438: '알아보세요.',
#  439: '전',
#  440: '관심이',
#  441: '때네요.',
#  442: '지나갈',
#  443: '않았으면',
#  444: '이별',
#  445: '맘',
#  446: '따로',
#  447: '상황을',
#  448: '흘렀네요.',
#  449: '빨리',
#  450: '필요하죠.',
#  451: '무시하세요.',
#  452: '시작이',
#  453: '필요',
#  454: '바뀔',
#  455: '만들어보세요.',
#  456: '친구들과',
#  457: '축하드려요.',
#  458: '있어도',
#  459: '오늘은',
#  460: '버리세요.',
#  461: '상대방을',
#  462: '필요는',
#  463: '아닐까요.',
#  464: '뭘',
#  465: '아니라고',
#  466: '않을까요.',
#  467: '기다려보세요.',
#  468: '진심으로',
#  469: '알고',
#  470: '연락해',
#  471: '가지세요.',
#  472: '실감이',
#  473: '않으니까요.',
#  474: '괜찮아질',
#  475: '잊는',
#  476: '호감을',
#  477: '호감이',
#  478: '사귀고',
#  479: '어서',
#  480: '드는',
#  481: '일',
#  482: '돈을',
#  483: '피할',
#  484: '준비해보세요.',
#  485: '선택을',
#  486: '기다릴',
#  487: '쐬고',
#  488: '살고',
#  489: '자신',
#  490: '내일은',
#  491: '자신에',
#  492: '변화를',
#  493: '아무',
#  494: '안해도',
#  495: '주지',
#  496: '없다고',
#  497: '성격이',
#  498: '말이에요.',
#  499: '아닐',
#  500: '인생은',
#  501: '소중한',
#  502: '이유를',
#  503: '용기가',
#  504: '사람으로',
#  505: '충분해요.',
#  506: '화장실',
#  507: '상대를',
#  508: '못한',
#  509: '예쁘게',
#  510: '받지',
#  511: '마스크',
#  512: '당신',
#  513: '어쩔',
#  514: '하루',
#  515: '서로의',
#  516: '사람에게',
#  517: '당당하게',
#  518: '직장',
#  519: '끝이',
#  520: '당신도',
#  521: '제대로',
#  522: '진정한',
#  523: '있길',
#  524: '상처를',
#  525: '하는게',
#  526: '한동안은',
#  527: '후폭풍이',
#  528: '어느',
#  529: '아니라면',
#  530: '방법이에요.',
#  531: '이별의',
#  532: '달라지는',
#  533: '행복한',
#  534: '있지만',
#  535: '짝사랑',
#  536: '정리하는게',
#  537: '부담스럽지',
#  538: '기회가',
#  539: '가요.',
#  540: '거예요!',
#  541: '힘들겠네요.',
#  542: '행복할',
#  543: '점점',
#  544: '없나봐요.',
#  545: '혼자가',
#  546: '내세요.',
#  547: '피하세요.',
#  548: '공부',
#  549: '중요하죠.',
#  550: '필요할',
#  551: '있어',
#  552: '적어보세요.',
#  553: '사람들에게',
#  554: '하셨네요.',
#  555: '그래서',
#  556: '않게',
#  557: '좋아해요.',
#  558: '기다리는',
#  559: '사용해보세요.',
#  560: '말도',
#  561: '생각은',
#  562: '가능할',
#  563: '순간',
#  564: '일이네요.',
#  565: '때를',
#  566: '만나는',
#  567: '눈이',
#  568: '말하는',
#  569: '듯',
#  570: '쉽게',
#  571: '잠이',
#  572: '깊은',
#  573: '좋죠!',
#  574: '거예요',
#  575: '생각하지',
#  576: '없이',
#  577: '좋겠지만',
#  578: '오늘도',
#  579: '무엇이든',
#  580: '나서',
#  581: '푹',
#  582: '용기내서',
#  583: '고백해보세요.',
#  584: '되기도',
#  585: '당장',
#  586: '가능성이',
#  587: '사람의',
#  588: '필요하겠네요.',
#  589: '아프네요.',
#  590: '힘들지',
#  591: '힘들었겠어요.',
#  592: '사랑한',
#  593: '상대방이',
#  594: '잊을',
#  595: '최선의',
#  596: '연락하지',
#  597: '차분히',
#  598: '때론',
#  599: '고민',
#  600: '자연스럽게',
#  601: '사랑한다면',
#  602: '그렇지만',
#  603: '감정에',
#  604: '헷갈리게',
#  605: '확실히',
#  606: '위로해',
#  607: '다음',
#  608: '따뜻하게',
#  609: '생각이에요.',
#  610: '결정을',
#  611: '쉬는',
#  612: '생각만',
#  613: '믿어보세요.',
#  614: '옆에',
#  615: '있을거예요.',
#  616: '다르겠지만',
#  617: '능력이',
#  618: '사람이랑',
#  619: '병원에',
#  620: '걱정하지',
#  621: '곳에서',
#  622: '돌려보세요.',
#  623: '그렇지',
#  624: '여행을',
#  625: '낫죠.',
#  626: '있지',
#  627: '이야기를',
#  628: '사람과',
#  629: '저',
#  630: '생각하는',
#  631: '해서',
#  632: '받는',
#  633: '부럽네요.',
#  634: '정신',
#  635: '이야기',
#  636: '온전히',
#  637: '거니',
#  638: '나눠보세요.',
#  639: '나이는',
#  640: '시원한',
#  641: '없겠네요.',
#  642: '어때요?',
#  643: '상황이',
#  644: '부러워요.',
#  645: '울어도',
#  646: '엄청',
#  647: '잘했어요.',
#  648: '의사를',
#  649: '바쁜가봐요.',
#  650: '건강에',
#  651: '돈',
#  652: '풀릴',
#  653: '물',
#  654: '사랑하고',
#  655: '걸어보세요.',
#  656: '쉬고',
#  657: '나가세요.',
#  658: '때는',
#  659: '곳에',
#  660: '적극적으로',
#  661: '영화',
#  662: '남을',
#  663: '안돼요.',
#  664: '일도',
#  665: '가지고',
#  666: '행복하게',
#  667: '사소한',
#  668: '연락하고',
#  669: '준비를',
#  670: '친구',
#  671: '하나봐요.',
#  672: '사람에',
#  673: '마다',
#  674: '만들어요.',
#  675: '이겨낼',
#  676: '했나봐요.',
#  677: '끝은',
#  678: '됩니다.',
#  679: '가슴',
#  680: '잊으세요.',
#  681: '거겠죠.',
#  682: '연락이',
#  683: '후회가',
#  684: '진심을',
#  685: '지내고',
#  686: '우세요.',
#  687: '있게',
#  688: '어떻게',
#  689: '순',
#  690: '편한',
#  691: '즐기세요.',
#  692: '습관이에요.',
#  693: '듣고',
#  694: '못하고',
#  695: '못하는',
#  696: '지금이라도',
#  697: '맞았나봐요.',
#  698: '공부는',
#  699: '쉬어도',
#  700: '약',
#  701: '누가',
#  702: '바람',
#  703: '감사합니다.',
#  704: '마음으로',
#  705: '말은',
#  706: '들어보세요.',
#  707: '알면',
#  708: '크게',
#  709: '많을',
#  710: '수록',
#  711: '나이가',
#  712: '축하해요!',
#  713: '도움을',
#  714: '파이팅!',
#  715: '태어난',
#  716: '오는',
#  717: '못할',
#  718: '어려워요.',
#  719: '노래',
#  720: '시기가',
#  721: '힘든가봅니다.',
#  722: '자신만',
#  723: '드셔보세요.',
#  724: '로맨틱하네요.',
#  725: '써보세요.',
#  726: '슬프네요.',
#  727: '얼굴',
#  728: '그대로',
#  729: '따뜻한',
#  730: '상처가',
#  731: '인생이',
#  732: '똑같은',
#  733: '보통',
#  734: '갈',
#  735: '골라보세요.',
#  736: '선택일',
#  737: '부탁해보세요.',
#  738: '선이',
#  739: '가고',
#  740: '마련이죠.',
#  741: '그만큼',
#  742: '받고',
#  743: '친구한테',
#  744: '나은',
#  745: '스스로에게',
#  746: '좋지만',
#  747: '연락은',
#  748: '고생했어요.',
#  749: '있다고',
#  750: '다르겠죠.',
#  751: '않나봐요.',
#  752: '좋아하는지',
#  753: '가지',
#  754: '가기',
#  755: '선물이',
#  756: '대해',
#  757: '찾아올',
#  758: '은연',
#  759: '있나요.',
#  760: '복잡하겠어요.',
#  761: '말할',
#  762: '생각할',
#  763: '솔직한',
#  764: '마련이에요.',
#  765: '아니니까요.',
#  766: '있겠죠.',
#  767: '않겠지만',
#  768: '저한테',
#  769: '이런',
#  770: '지났네요.',
#  771: '감정이',
#  772: '이별에는',
#  773: '헤아리는',
#  774: '데는',
#  775: '있더라고요.',
#  776: '있지요.',
#  777: '분위기',
#  778: '있을지도',
#  779: '위로가',
#  780: '기대세요.',
#  781: '감정의',
#  782: '본인의',
#  783: '아닐까요?',
#  784: '짝사랑이',
#  785: '표현해보세요.',
#  786: '바쁘거나',
#  787: '다가가보세요.',
#  788: '사귀기',
#  789: '새로',
#  790: '모르고',
#  791: '두',
#  792: '관리하세요.',
#  793: '아름다운',
#  794: '혼자도',
#  795: '알게',
#  796: '밥',
#  797: '늘어요.',
#  798: '내보세요.',
#  799: '챙겨드세요.',
#  800: '좋아하나봐요.',
#  801: '지금처럼',
#  802: '삶을',
#  803: '혼자만',
#  804: '상대에게',
#  805: '곁에',
#  806: '있다는',
#  807: '신나는',
#  808: '줘보세요.',
#  809: '현실을',
#  810: '지도',
#  811: '취해보세요.',
#  812: '다가가',
#  813: '운동',
#  814: '목소리를',
#  815: '그러고',
#  816: '동안',
#  817: '믿음이',
#  818: '말해주세요.',
#  819: '노력하는',
#  820: '있으니',
#  821: '건지',
#  822: '집',
#  823: '거리를',
#  824: '힘내세요!',
#  825: '노력하겠습니다.',
#  826: '알려주세요.',
#  827: '감고',
#  828: '먹는',
#  829: '솔직하게',
#  830: '남에게',
#  831: '행복은',
#  832: '있어서',
#  833: '돈이',
#  834: '남의',
#  835: '현재를',
#  836: '맛나게',
#  837: '회원정보',
#  838: '찾기를',
#  839: '긍정적인',
#  840: '읽어보세요.',
#  841: '사람들',
#  842: '생각했나봐요.',
#  843: '회사와',
#  844: '대해서',
#  845: '공부해서',
#  846: '그렇다면',
#  847: '혹시',
#  848: '추천해요.',
#  849: '모습이',
#  850: '인생을',
#  851: '숨',
#  852: '관계를',
#  853: '받아보세요.',
#  854: '챙겨',
#  855: '누구든',
#  856: '우산',
#  857: '언젠가',
#  858: '한잔',
#  859: '자체가',
#  860: '하나',
#  861: '방법이',
#  862: '뭔지',
#  863: '하면서',
#  864: '은근',
#  865: '바쁜',
#  866: '응원합니다!',
#  867: '사람인가봐요.',
#  868: '모습을',
#  869: '회사는',
#  870: '거면',
#  871: '스트레스가',
#  872: '여행도',
#  873: '바쁘게',
#  874: '이렇게',
#  875: '말이네요.',
#  876: '글로',
#  877: '우리는',
#  878: '나면',
#  879: '기다리고',
#  880: '내는',
#  881: '극복할',
#  882: '회사',
#  883: '나타날',
#  884: '이상',
#  885: '사랑했나봐요.',
#  886: '보내주세요.',
#  887: '힘들었을',
#  888: '정리할',
#  889: '때문에',
#  890: '그녀를',
#  891: '드릴게요.',
#  892: '단단히',
#  893: '흔들리지',
#  894: '거기까지인가봐요.',
#  895: '이',
#  896: '헤어진',
#  897: '사랑이네요.',
#  898: '머리랑',
#  899: '가슴이',
#  900: '것은',
#  901: '그분',
#  902: '있나봅니다.',
#  903: '괜찮아졌길',
#  904: '다르겠지요.',
#  905: '있기',
#  906: '물어보는게',
#  907: '소식이네요.',
#  908: '좋아하면',
#  909: '사랑으로',
#  910: '관심사를',
#  911: '따뜻할',
#  912: '썸의',
#  913: '이성으로',
#  914: '후가',
#  915: '저를',
#  916: '자체로',
#  917: '다음부터는',
#  918: '일부터',
#  919: '운동을',
#  920: '용기',
#  921: '건강',
#  922: '증거를',
#  923: '노력하면',
#  924: '타이밍이',
#  925: '연습이',
#  926: '말씀하세요.',
#  927: '후회는',
#  928: '아니죠.',
#  929: '재미가',
#  930: '만남이었길',
#  931: '궁금해요.',
#  932: '자세히',
#  933: '떠나보세요.',
#  934: '괜찮은',
#  935: '바라지',
#  936: '기다리면',
#  937: '선물은',
#  938: '아무렇지도',
#  939: '나',
#  940: '좋아하고',
#  941: '정해보세요.',
#  942: '시작하세요.',
#  943: '하나라도',
#  944: '현실의',
#  945: '알아보고',
#  946: '걱정이',
#  947: '봐도',
#  948: '속',
#  949: '과정이',
#  950: '만든',
#  951: '지난',
#  952: '시원하게',
#  953: '위로봇입니다.',
#  954: '생각해도',
#  955: '비교하지',
#  956: '뭐라도',
#  957: '기분전환을',
#  958: '지내는',
#  959: '완벽한',
#  960: '수는',
#  961: '사랑할',
#  962: '가능해요.',
#  963: '참고',
#  964: '참아보세요.',
#  965: '기다려주세요.',
#  966: '아니네요.',
#  967: '하지마세요.',
#  968: '귀',
#  969: '최고죠.',
#  970: '데이트를',
#  971: '습관을',
#  972: '상처받지',
#  973: '멋져요.',
#  974: '여러',
#  975: '여행',
#  976: '드세요!',
#  977: '시작',
#  978: '내일',
#  979: '재미',
#  980: '고백을',
#  981: '있겠네요.',
#  982: '어울리는',
#  983: '몸이',
#  984: '분이',
#  985: '풀어보세요.',
#  986: '않아서',
#  987: '당연하죠.',
#  988: '일이죠.',
#  989: '외로운',
#  990: '성공하길',
#  991: '정리를',
#  992: '만나면',
#  993: '약을',
#  994: '유지하는',
#  995: '사람이라면',
#  996: '해야죠.',
#  997: '힘들어하지',
#  998: '주변에',
#  999: '아니면',
#  1000: '편할',
#  ...}

# %%
a_num_words = min(VOCAB_SIZE, len(A_tokenizer.index_word))
a_max_len = min(15, max(len(seq) for seq in A_inputs_seq))

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

Q_inputs_padded = pad_sequences(Q_inputs_seq, maxlen=q_max_len, padding='pre')
A_inputs_padded = pad_sequences(A_inputs_seq, maxlen=a_max_len, padding='post')
A_targets_padded = pad_sequences(A_targets_seq, maxlen=a_max_len, padding='post')

# %%
Q_inputs_padded.shape, A_inputs_padded.shape, A_targets_padded.shape
# Out:
# ((11823, 15), (11823, 15), (11823, 15))

# %% [markdown]
# ### 모델 생성 및 학습

# %%
for i, vects in enumerate(df.values):
    print(vects)   # ['질문', '답변'] 형태로 출력한다.
    if i == 3:
        break
# Out:
# ['12시 땡!' '하루가 또 가네요.']
# ['1지망 학교 떨어졌어' '위로해 드립니다.']
# ['3박4일 놀러가고 싶다' '여행은 언제나 좋죠.']
# ['3박4일 정도 놀러가고 싶다' '여행은 언제나 좋죠.']

# %%
import numpy as np
import pandas as pd

def make_embedding_matrix(num_words, embedding_dim, tokenizer, df):

    embedding_matrix = np.zeros((num_words + 1, embedding_dim), dtype=np.float32)

    texts = pd.concat([df['Q'], df['A']]).astype(str).tolist()

    pretrained_embedding = {}
    vocab = tokenizer.word_index.keys()
    for word in vocab:
        pretrained_embedding[word] = np.random.normal(
            loc=0.0, scale=0.05, size=(embedding_dim,)
        ).astype(np.float32)

    # tokenizer 단어 인덱스와 매핑
    for word, index in tokenizer.word_index.items():
        if index > num_words:
            continue
        vects_ = pretrained_embedding.get(word)
        if vects_ is not None:
            embedding_matrix[index] = vects_

    return embedding_matrix

# %%
EMBEDDING_DIM = 100

qna_embedding_matrix = make_embedding_matrix(
    q_num_words,
    EMBEDDING_DIM,
    Q_tokenizer,
    df   
)

print(qna_embedding_matrix.shape)
# Out:
# (10001, 100)

# %%
q_word_index = ['<pad>'] + list(Q_tokenizer.index_word.values())[:10000]

# %%
import pandas as pd

pd.DataFrame(qna_embedding_matrix, index=q_word_index)
# Out:
#              0         1         2         3         4         5         6   \
# <pad>  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# <OOV> -0.042541  0.074249  0.117380  0.074609 -0.042105  0.023713  0.018082
# 너무     0.049486  0.005963  0.021781  0.063960  0.049225  0.010017 -0.009300
# 좋아하는   0.091493  0.022195 -0.001610 -0.020099 -0.088268 -0.040278  0.064456
# 거      0.086222  0.044359 -0.037667  0.064226  0.038595  0.018800 -0.035402
# ...         ...       ...       ...       ...       ...       ...       ...
# 남자들의  -0.141546  0.044652 -0.034394  0.011803 -0.030309  0.132078 -0.089134
# 이별할때는 -0.016174 -0.071335  0.029518  0.034737  0.027418 -0.003051 -0.012686
# 갖지    -0.076492  0.057769 -0.020232 -0.068360  0.033907  0.006152 -0.024582
# 않게     0.013372  0.122001  0.051015  0.093813  0.032818  0.022463 -0.055821
# 이별해야   0.024444  0.025393  0.015048  0.015084 -0.074276 -0.029191  0.005465
#
#              7         8         9   ...        90        91        92  \
# <pad>  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# <OOV>  0.027844  0.031752  0.043335  ...  0.042901  0.039348  0.010680
# 너무    -0.011502 -0.065634  0.060040  ...  0.082181  0.035144 -0.117430
# 좋아하는  -0.063074 -0.009800 -0.091817  ... -0.093083  0.080091 -0.010653
# 거     -0.048974 -0.037487 -0.045912  ... -0.022312  0.068568 -0.050065
# ...         ...       ...       ...  ...       ...       ...       ...
# 남자들의   0.003070  0.069940 -0.087952  ... -0.070514  0.055980  0.016964
# 이별할때는  0.030409 -0.014167 -0.021306  ...  0.040587  0.075810 -0.001078
# 갖지    -0.004494  0.025986  0.011315  ...  0.098123 -0.054118  0.018182
# 않게    -0.054341  0.069925 -0.012800  ...  0.107498 -0.038478 -0.014225
# 이별해야   0.102285 -0.111113 -0.040970  ...  0.060820  0.033078  0.106666
#
#              93        94        95        96        97        98        99
# <pad>  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# <OOV>  0.026275  0.050154  0.012012 -0.009921  0.013622 -0.011234  0.033917
# 너무     0.047538 -0.016796 -0.011328 -0.034660  0.062217  0.012783 -0.036920
# 좋아하는  -0.017596  0.073729  0.030837 -0.026070  0.054426  0.020693 -0.056653
# 거     -0.006668 -0.058207  0.020351  0.034420 -0.046811 -0.026853  0.017475
# ...         ...       ...       ...       ...       ...       ...       ...
# 남자들의   0.016148  0.061721 -0.023099  0.072831 -0.040339  0.023678 -0.035215
# 이별할때는  0.023524 -0.062027 -0.027671  0.048453  0.067351 -0.069462  0.100925
# 갖지     0.019961 -0.011474 -0.068503  0.007346 -0.078768  0.010742  0.003598
# 않게    -0.021886  0.028652 -0.015753  0.003900 -0.042451  0.027515  0.035647
# 이별해야  -0.026899  0.096317 -0.006051  0.056494  0.050071  0.125439  0.083572
#
# [10001 rows x 100 columns]

# %% [markdown]
# ##### 인코더 생성

# %%
from tensorflow.keras import layers, models

LATENT_DIM = 512

encoder_inputs = layers.Input(shape=(q_max_len,))
en_embedding_layer = layers.Embedding(q_num_words+1, EMBEDDING_DIM, weights=[qna_embedding_matrix])
x = en_embedding_layer(encoder_inputs)
encoder_outputs, h, c = layers.LSTM(LATENT_DIM, return_state=True)(x)
encoder_states = [h, c]

encoder_model = models.Model(inputs=encoder_inputs, outputs=encoder_states)
encoder_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 15)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 15, 100)        │     1,000,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ [(None, 512), (None,   │     1,255,424 │
# │                                 │ 512), (None, 512)]     │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,255,524 (8.60 MB)
#  Trainable params: 2,255,524 (8.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### 디코더(teacher-forcing 모델) 생성

# %%
decoder_inputs = layers.Input(shape=[a_max_len,])
ko_embedding_layer = layers.Embedding(a_num_words+1, EMBEDDING_DIM)
x = ko_embedding_layer(decoder_inputs)

decoder_lstm = layers.LSTM(LATENT_DIM, return_sequences=True, return_state=True)
x, h, c = decoder_lstm(x, initial_state=encoder_states)

decoder_dense = layers.Dense(a_num_words+1, activation='softmax')
decoder_outputs = decoder_dense(x)

decoder_teacher_forcing_model = models.Model(
    inputs = [encoder_inputs, decoder_inputs],
    outputs = decoder_outputs
)

decoder_teacher_forcing_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 15)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 15)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 15, 100)   │  1,000,100 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 15, 100)   │  1,000,100 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 512),     │  1,255,424 │ embedding[0][0]   │
# │                     │ (None, 512),      │            │                   │
# │                     │ (None, 512)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 15, 512), │  1,255,424 │ embedding_1[0][0… │
# │                     │ (None, 512),      │            │ lstm[0][1],       │
# │                     │ (None, 512)]      │            │ lstm[0][2]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 15, 10001) │  5,130,513 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,641,561 (36.78 MB)
#  Trainable params: 9,641,561 (36.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### 학습

# %%
decoder_teacher_forcing_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

history = decoder_teacher_forcing_model.fit(
    [Q_inputs_padded, A_inputs_padded],
    A_targets_padded,
    batch_size = 64,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 71s 464ms/step - accuracy: 0.7390 - loss: 2.4929 - val_accuracy: 0.7134 - val_loss: 2.6142
# Epoch 2/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.7651 - loss: 1.9033 - val_accuracy: 0.7136 - val_loss: 2.5984
# Epoch 3/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 60s 409ms/step - accuracy: 0.7652 - loss: 1.8130 - val_accuracy: 0.7141 - val_loss: 2.6177
# Epoch 4/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 61s 411ms/step - accuracy: 0.7665 - loss: 1.7514 - val_accuracy: 0.7119 - val_loss: 2.6647
# Epoch 5/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 72s 488ms/step - accuracy: 0.7695 - loss: 1.6995 - val_accuracy: 0.7075 - val_loss: 2.7167
# Epoch 6/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.7725 - loss: 1.6485 - val_accuracy: 0.7081 - val_loss: 2.7456
# Epoch 7/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 64s 435ms/step - accuracy: 0.7744 - loss: 1.5951 - val_accuracy: 0.7077 - val_loss: 2.7864
# Epoch 8/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 62s 417ms/step - accuracy: 0.7771 - loss: 1.5414 - val_accuracy: 0.7086 - val_loss: 2.8297
# Epoch 9/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 62s 420ms/step - accuracy: 0.7807 - loss: 1.4842 - val_accuracy: 0.7091 - val_loss: 2.8674
# Epoch 10/10
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 63s 425ms/step - accuracy: 0.7848 - loss: 1.4256 - val_accuracy: 0.7107 - val_loss: 2.9097

# %% [markdown]
# ### 모델 추론

# %% [markdown]
# ### 디코더 (추론 모델) 생성

# %%
# from os import initgroups

decoder_hidden_state = layers.Input(shape=(LATENT_DIM,))
decoder_cell_state = layers.Input(shape=(LATENT_DIM,))
decoder_states_inputs = [decoder_hidden_state, decoder_cell_state]

decoder_single_input = layers.Input(shape=(1,))

x = ko_embedding_layer(decoder_single_input)

x, h, c = decoder_lstm(x, initial_state = decoder_states_inputs)
decoder_states = [h, c]

decoder_outputs_ = decoder_dense(x)

decoder_interence_model = models.Model(
    inputs=[decoder_single_input] + decoder_states_inputs,
    outputs=[decoder_outputs_] + decoder_states
)
decoder_interence_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 1, 100)    │  1,000,100 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 1, 512),  │  1,255,424 │ embedding_1[1][0… │
# │                     │ (None, 512),      │            │ input_layer_2[0]… │
# │                     │ (None, 512)]      │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 10001)  │  5,130,513 │ lstm_1[1][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,386,037 (28.18 MB)
#  Trainable params: 7,386,037 (28.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 추론 함수

# %%
def translate(input_seq):        # 번역 함수
  encoder_states_value = encoder_model.predict(input_seq)
  decoder_states_value= encoder_states_value

  bos_index = A_tokenizer.word_index['<bos>']
  eos_index = A_tokenizer.word_index['<eos>']

  target_seq = np.zeros((1, 1))  # 초기화
  target_seq[0, 0] = bos_index

  output_sentences = []

  for _ in range(a_max_len):
    output_tokens, h, c = decoder_interence_model.predict([target_seq] + decoder_states_value)

    pred_proba = output_tokens[0, 0, :]
    pred_index = np.argmax(pred_proba)

    if pred_index == eos_index:
      break

    if pred_index > 0:
      word = A_tokenizer.index_word[pred_index]
      output_sentences.append(word)

    target_seq[0, 0] = pred_index # 현재로 변경
    decoder_states_value = [h, c]
  return " ".join(output_sentences)

# %% [markdown]
# ### 테스트

# %%
for _ in range(5):
  idx = np.random.choice(len(A_inputs_padded))
  input_seq = A_inputs_padded[idx:idx+1]
  output_sent = translate(input_seq)
  display("입력 답:", A_inputs[idx])
  display("학습한 질문:", Q_inputs[idx])
  display("추론한 국문:", output_sent)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# '입력 답:'
# '<bos> 나를 사랑하고 상대를 사랑하는 여유를 갖게 되길 바라요.'
# '학습한 질문:'
# '여유가 너무 없어'
# '추론한 국문:'
# '매력을 매력을 매력을 성격이 자리에서 성격이 자리에서 성격이 삶을 마음에 그러든지 삶을 그랬나봐요. 매력을 매력을'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# '입력 답:'
# '<bos> 딱 보면 떠오르는 걸로 해보세요.'
# '학습한 질문:'
# '남친 생겼는데 호칭 어떻게 해?'
# '추론한 국문:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# '입력 답:'
# '<bos> 좋은 친구들 두셨네요!'
# '학습한 질문:'
# '친구들이 브라이덜샤워해준대'
# '추론한 국문:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# '입력 답:'
# '<bos> 대화를 해보세요.'
# '학습한 질문:'
# '여자친구의 성적 취향을 이해못하겠어.'
# '추론한 국문:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# '입력 답:'
# '<bos> 많이 사랑한 사람인가봐요.'
# '학습한 질문:'
# '잘해준것 같은데도 느끼는 미안함'
# '추론한 국문:'
# '좋은 좋죠.'

# %% [markdown]
# ### 간단한 Chatbot 구현
#
# 1. 사용자의 입력을 받아 (처리)
# 2. 추론 함수에 전달해서
# 3. 응답을 출력
# 4. 1~3 '종료' 전까지 반복

# %%
for _ in range(5):
  idx = np.random.choice(len(Q_inputs_padded))
  input_seq = Q_inputs_padded[idx:idx+1]
  output_sent = translate(input_seq)
  display("입력 질문:", Q_inputs[idx])
  display("학습한 답:", A_inputs[idx])
  display("추론한 답:", output_sent)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# '입력 질문:'
# '선물로 인형 받았어'
# '학습한 답:'
# '<bos> 고맙다고 말해 주세요.'
# '추론한 답:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# '입력 질문:'
# '좋아하는 남자애한테 자연스럽게 연락하는 방법 뭐 있을까.'
# '학습한 답:'
# '<bos> 뭐하고 있는지 물어봐요.'
# '추론한 답:'
# '좋은 싶은 해보세요.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# '입력 질문:'
# '고민 있어'
# '학습한 답:'
# '<bos> 네 말씀하세요.'
# '추론한 답:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# '입력 질문:'
# '이별한지 1달'
# '학습한 답:'
# '<bos> 한달 동안 잘 참아왔네요.'
# '추론한 답:'
# '좋은 좋죠.'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# '입력 질문:'
# '썸 타는 사람이 셀카 보내는 건 뭐야?'
# '학습한 답:'
# '<bos> 봐달라는 거겠죠.'
# '추론한 답:'
# '좋은 자신에 대해서 더 공부해서 자신감을 가져보세요.'
